# %%
import boto3
from datetime import datetime
import os

# %%
BLOG_INTRO = "I'm Tomás Jaramillo from Colombia, and Code Beats is my personal blog on web development, coffee ☕, beer 🍺, data science 📊, and other random stuff."
BLOG_TITLE = "Code Beats"
SITE_META_DESCRIPTION = "Code Beats is Tomás Jaramillo's blog on web development, coffee, beer, data science, and other random stuff."
SITE_TITLE = "Code Beats | Tomás Jaramillo's blog"
SITE_CANONICAL_URL = "https://codebeats.net/"
SITE_AUTHOR = "Tomás Jaramillo Quintero"
BLOG_SEO_SUBFOLDER = "blogpost"
GOOGLE_TAG_MANAGER_ID = "GTM-TFZR3NL"
TWITTER_HANDLE = "TheCodeBeats"
GITHUB_HANDLE = "thecodebeatz"
AWS_DYNAMO_TABLE = ""
AWS_REGION = "us-east-1"
AWS_ACCESS_KEY = ""
AWS_SECRET_KEY = ""
BUCKET_NAME = ''

# %%
def date_to_nice_string(my_date):
    my_date = datetime.strptime(my_date, "%Y-%m-%dT%H:%M:%S.%fZ")
    month = [
        "Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"
    ]
    return f"{month[my_date.month - 1]} {my_date.day}, {my_date.year}"

def date_to_unix(date_string):
    return datetime.strptime(date_string, "%Y-%m-%dT%H:%M:%S.%fZ").timestamp()

# %%
def get_blogpost_content(postid):
    dynamodb = boto3.client('dynamodb', region_name=AWS_REGION, aws_access_key_id=AWS_ACCESS_KEY, aws_secret_access_key=AWS_SECRET_KEY)

    params = {
        'TableName': AWS_DYNAMO_TABLE,
        'Key': {
            'post_folder': {'S': postid}
        }
    }

    blogpost_content = dynamodb.get_item(**params).get("Item", [])
    
    return blogpost_content

# %%
HTMLBODY = f"""
<!DOCTYPE html>
<html lang="en-us">

<head>
    <title>{BLOG_TITLE}</title>
    <meta name="author" content="{SITE_AUTHOR}" />
    <link rel="canonical" href="{SITE_CANONICAL_URL}" />
    <meta name="description" content="{SITE_META_DESCRIPTION}" />
    <meta name="twitter:card" content="{SITE_META_DESCRIPTION}" />
    <meta name="twitter:title" content="{SITE_AUTHOR}" />
    <meta name="twitter:description" content="{SITE_META_DESCRIPTION}" />
    <meta property="og:title" content="{SITE_AUTHOR}" />
    <meta property="og:description" content="{SITE_META_DESCRIPTION}"/>
    <meta property="og:url" content="{SITE_CANONICAL_URL}" />
    <meta name="robots" content="index, follow" />
    <meta name="googlebot" content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" />
    <meta name="bingbot" content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" />
    <meta name="viewport" content="width=device-width, initial-scale=1" />
    <link rel="apple-touch-icon" sizes="57x57" href="{SITE_CANONICAL_URL}apple-icon-57x57.png" />
    <link rel="apple-touch-icon" sizes="60x60" href="{SITE_CANONICAL_URL}apple-icon-60x60.png" />
    <link rel="apple-touch-icon" sizes="72x72" href="{SITE_CANONICAL_URL}apple-icon-72x72.png" />
    <link rel="apple-touch-icon" sizes="76x76" href="{SITE_CANONICAL_URL}apple-icon-76x76.png" />
    <link rel="apple-touch-icon" sizes="114x114" href="{SITE_CANONICAL_URL}apple-icon-114x114.png" />
    <link rel="apple-touch-icon" sizes="120x120" href="{SITE_CANONICAL_URL}apple-icon-120x120.png" />
    <link rel="apple-touch-icon" sizes="144x144" href="{SITE_CANONICAL_URL}apple-icon-144x144.png" />
    <link rel="apple-touch-icon" sizes="152x152" href="{SITE_CANONICAL_URL}apple-icon-152x152.png" />
    <link rel="apple-touch-icon" sizes="180x180" href="{SITE_CANONICAL_URL}apple-icon-180x180.png" />
    <link rel="icon" type="image/png" sizes="192x192" href="{SITE_CANONICAL_URL}android-icon-192x192.png" />
    <link rel="icon" type="image/png" sizes="32x32" href="{SITE_CANONICAL_URL}favicon-32x32.png" />
    <link rel="icon" type="image/png" sizes="96x96" href="{SITE_CANONICAL_URL}favicon-96x96.png" />
    <link rel="icon" type="image/png" sizes="16x16" href="{SITE_CANONICAL_URL}favicon-16x16.png" />
    <link rel="manifest" href="{SITE_CANONICAL_URL}manifest.json" />
    <meta name="msapplication-TileColor" content="#ffffff" />
    <meta name="msapplication-TileImage" content="/ms-icon-144x144.png" />
    <meta name="theme-color" content="#ffffff" />
    <style>
    @import url(https://fonts.googleapis.com/css?family=Heebo:400,700|Open+Sans:400,700&display=swap);
    
    :root {{
      --color: #f04859;
      --transition-time: 0.5s;
    }}
    
    * {{
      box-sizing: border-box;
    }}
    
    html {{
      line-height: 1.6;
    }}
    
    body {{
      margin: 0;
      min-height: 100vh;
      font-family: "Open Sans";
      background: #fff;
    }}
    
    a {{
      text-decoration: none;
    }}
    
    h1 {{
      font-size: 1.2em;
      margin: 1.5em;
      color: #999;
    }}
    
    h3,
    h4,
    h5,
    h6 {{
      color: #222;
    }}
    
    #rootcontainer {{
      display: flex;
    }}
    
    #site_name {{
      display: block;
      font-size: 2em;
      margin-block-start: 0.67em;
      margin-block-end: 0.67em;
      margin-inline-start: 0;
      margin-inline-end: 0;
      font-weight: 700;
    }}
    
    #site_name,
    .app-header h1,
    .app-header h2,
    .app-header h3,
    .app-header h4,
    .app-header h5,
    .app-header h6 {{
      color: #fff;
    }}
    
    .app-header p {{
      color: #999;
    }}
    
    a:hover {{
      color: #222;
    }}
    
    code {{
      font-family: monospace, monospace;
      font-size: 1em;
      color: #000;
    }}
    
    pre {{
      overflow: auto;
    }}
    
    pre code {{
      font-size: 0.8em;
    }}
    
    ::selection {{
      background: rgba(175, 186, 196, 0.4);
    }}
    
    ::-moz-selection {{
      background: rgba(175, 186, 196, 0.4);
    }}
    
    .app-header {{
      padding: 2vw;
      background: #242930;
      text-align: center;
    }}
    
    .app-header-social {{
      font-size: 2em;
      color: #fff;
    }}
    
    .app-header-social a {{
      margin: 0 0.1em;
      color: #666;
    }}
    
    .posts {{
      margin: 0 0 4vw 5vw;
    }}
    
    .posts a {{
      color: #f04859;
      transition: color 0.35s;
      text-decoration: none;
    }}
    
    .posts h1 {{
      margin-left: 0;
    }}
    
    .post-title {{
      color: #222;
    }}
    
    .post-content pre {{
      border-left: 0.4em solid rgba(87, 204, 138, 0.8);
      padding-left: 1em;
    }}
    
    .post-content img {{
      max-width: 100%;
    }}
    
    @media screen and (max-width: 450px) {{
      .info {{
        display: block;
        text-align: center;
      }}
    
      .info h1 {{
        margin: 0;
      }}
    }}
    
    @media (min-width: 940px) {{
      .app-header {{
        position: fixed;
        top: 0;
        left: 0;
        width: 20vw;
        height: 100%;
      }}
    
      .app-container {{
        margin-left: 20vw;
        margin-right: 2vw;
        width: 70vw;
        padding-right: 3vw;
      }}
    }}
    
    @media (max-width: 940px) {{
      .app-header {{
        padding: 5vw 4vw 3vw 4vw;
        background: #242930;
        text-align: center;
      }}
    
      .app-container {{
        width: 92vw;
      }}
    }}
    
    
    /*--blog----*/
    
    .blog-grid {{
      margin: 0 0 2em 2em;
    }}
    
    .blog-list-grid {{
      column-count: 3;
      column-gap: 30px;
    }}
    
    .blog-list {{
      float: left;
      width: 100%;
      -webkit-column-break-inside: avoid;
      page-break-inside: avoid;
      break-inside: avoid;
      page-break-inside: avoid;
    
      margin: 0 0 30px 0;
      background-color: #FFFFFF;
      -moz-box-shadow: 0 0 15px 2px rgba(0, 0, 0, 0.05);
      -o-box-shadow: 0 0 15px 2px rgba(0, 0, 0, 0.05);
      -webkit-box-shadow: 0 0 15px 2px rgba(0, 0, 0, 0.05);
      box-shadow: 0 0 15px 2px rgba(0, 0, 0, 0.05);
    }}
    
    .blog-list-description {{
      padding: 0 25px;
    }}
    
    .blog-list-description h4 {{
      color: #424C4C;
      font-size: 20px;
      line-height: 1.2;
      margin-bottom: 20px;
      margin-top:0;
    }}
    
    .blog-list-date {{
      color:#666;
      font-size:14px;
    }}
    
    .blog-list-description h4 a {{
      color: #f04859;
    }}
    
    .blog-list-description p {{
      font-size: 16px;
      line-height: 1.5;
    }}
    
    @media only screen and (max-width: 921px) {{
      .blog-list-grid {{
        column-count: 2;
      }}
    
    }}
    
    @media only screen and (max-width: 767px) {{
      .blog-list-grid {{
        column-count: 1;
      }}
    
    }}
    
    img {{
      max-width: 100%;
      height: auto;
    }}
    </style>
</head>
<!-- Google tag (gtag.js) -->
<script async src="https://www.googletagmanager.com/gtag/js?id=G-7T5E2GTJF4"></script>
<script>
  window.dataLayer = window.dataLayer || [];
  function gtag(){{dataLayer.push(arguments);}}
  gtag('js', new Date());

  gtag('config', 'G-7T5E2GTJF4');
</script>
<body>
<div id="root">
<div id="rootcontainer">
<div>
<div>
<header class="app-header">
    <a href="/">
        <div class="app-header-avatar">
            <img src="/codebeats_logo.svg" alt="React Logo" />
        </div>
    </a>
    <a href="/"><span id="site_name">{BLOG_TITLE}</span></a>
    <p>{BLOG_INTRO}</p>
    <div class="app-header-social">
        <a target="_blank" href="https://github.com/{GITHUB_HANDLE}" rel="noreferrer noopener">
            <svg xmlns="http://www.w3.org/2000/svg" width="35" height="35" viewBox="0 0 24 24" fill="none" stroke="currentColor" strokeWidth="2" strokeLinecap="round" strokeLinejoin="round" class="icon icon-github">
            <title>github</title>
            <path d="M9 19c-5 1.5-5-2.5-7-3m14 6v-3.87a3.37 3.37 0 0 0-.94-2.61c3.14-.35 6.44-1.54 6.44-7A5.44 5.44 0 0 0 20 4.77 5.07 5.07 0 0 0 19.91 1S18.73.65 16 2.48a13.38 13.38 0 0 0-7 0C6.27.65 5.09 1 5.09 1A5.07 5.07 0 0 0 5 4.77a5.44 5.44 0 0 0-1.5 3.78c0 5.42 3.3 6.61 6.44 7A3.37 3.37 0 0 0 9 18.13V22"></path>
            </svg>
        </a>
        <a target="_blank" href="https://twitter.com/{TWITTER_HANDLE}" rel="noreferrer noopener">
            <svg xmlns="http://www.w3.org/2000/svg" width="35" height="35" viewBox="0 0 24 24" fill="none" stroke="currentColor" strokeWidth="2" strokeLinecap="round" strokeLinejoin="round" class="icon icon-twitter">
            <title>twitter</title>
            <path d="M23 3a10.9 10.9 0 0 1-3.14 1.53 4.48 4.48 0 0 0-7.86 3v1A10.66 10.66 0 0 1 3 4s-4 9 5 13a11.64 11.64 0 0 1-7 2c9 5 20 0 20-11.5a4.5 4.5 0 0 0-.08-.83A7.72 7.72 0 0 0 23 3z"></path>
            </svg>
        </a>
    </div>
</header>
</div>
<main class="app-container">
    <h1>{BLOG_TITLE} blog post feed</h1>
    <article>
        <section class="cards-wrapper">
            <div class="blog-grid">
                <div class="container">
                    <div class="row">
                        <div class="col-md-12">
                            <div class="blog-list-grid">
"""

FOOTER = f"""
                            </div>
                        </div>
                    </div>
                </div>
            </div>
        </section>
    </article>
</main>

</div>
</div>
</div>
</body>
</html>
"""

# %%
def HTML_BLOGPOST_BODY(blog_post_title, blog_post_canonical_url, blog_post_date, blog_post_html, blog_post_tags):
    return f"""
<!DOCTYPE html>
<html lang="en-us">

<head>
    <title>{blog_post_title}</title>
    <meta name="author" content="{SITE_AUTHOR}" />
    <link rel="canonical" href="{blog_post_canonical_url}" />
    <meta name="description" content="{SITE_META_DESCRIPTION}" />
    <meta property="article:published_time" content="{blog_post_date}" />
    <meta property="article:modified_time" content="{blog_post_date}" />
    <meta name="twitter:card" content="{SITE_META_DESCRIPTION}" />
    <meta name="twitter:title" content="{SITE_AUTHOR}" />
    <meta name="twitter:description" content="{SITE_META_DESCRIPTION}" />
    <meta property="og:title" content="{SITE_AUTHOR}" />
    <meta property="og:description" content="{SITE_META_DESCRIPTION}"/>
    <meta property="og:url" content="{blog_post_canonical_url}" />
    <meta name="robots" content="index, follow" />
    <meta name="googlebot" content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" />
    <meta name="bingbot" content="index, follow, max-snippet:-1, max-image-preview:large, max-video-preview:-1" />
    <meta name="viewport" content="width=device-width, initial-scale=1" />
    <link rel="apple-touch-icon" sizes="57x57" href="{SITE_CANONICAL_URL}apple-icon-57x57.png" />
    <link rel="apple-touch-icon" sizes="60x60" href="{SITE_CANONICAL_URL}apple-icon-60x60.png" />
    <link rel="apple-touch-icon" sizes="72x72" href="{SITE_CANONICAL_URL}apple-icon-72x72.png" />
    <link rel="apple-touch-icon" sizes="76x76" href="{SITE_CANONICAL_URL}apple-icon-76x76.png" />
    <link rel="apple-touch-icon" sizes="114x114" href="{SITE_CANONICAL_URL}apple-icon-114x114.png" />
    <link rel="apple-touch-icon" sizes="120x120" href="{SITE_CANONICAL_URL}apple-icon-120x120.png" />
    <link rel="apple-touch-icon" sizes="144x144" href="{SITE_CANONICAL_URL}apple-icon-144x144.png" />
    <link rel="apple-touch-icon" sizes="152x152" href="{SITE_CANONICAL_URL}apple-icon-152x152.png" />
    <link rel="apple-touch-icon" sizes="180x180" href="{SITE_CANONICAL_URL}apple-icon-180x180.png" />
    <link rel="icon" type="image/png" sizes="192x192" href="{SITE_CANONICAL_URL}android-icon-192x192.png" />
    <link rel="icon" type="image/png" sizes="32x32" href="{SITE_CANONICAL_URL}favicon-32x32.png" />
    <link rel="icon" type="image/png" sizes="96x96" href="{SITE_CANONICAL_URL}favicon-96x96.png" />
    <link rel="icon" type="image/png" sizes="16x16" href="{SITE_CANONICAL_URL}favicon-16x16.png" />
    <link rel="manifest" href="{SITE_CANONICAL_URL}manifest.json" />
    <meta name="msapplication-TileColor" content="#ffffff" />
    <meta name="msapplication-TileImage" content="/ms-icon-144x144.png" />
    <meta name="theme-color" content="#ffffff" />
    <style>
    @import url(https://fonts.googleapis.com/css?family=Heebo:400,700|Open+Sans:400,700&display=swap);
    
    :root {{
      --color: #f04859;
      --transition-time: 0.5s;
    }}
    
    * {{
      box-sizing: border-box;
    }}
    
    html {{
      line-height: 1.6;
    }}
    
    body {{
      margin: 0;
      min-height: 100vh;
      font-family: "Open Sans";
      background: #fff;
    }}
    
    a {{
      text-decoration: none;
    }}
    
    h1 {{
      font-size: 1.2em;
      margin: 1.5em;
      color: #999;
    }}
    
    h3,
    h4,
    h5,
    h6 {{
      color: #222;
    }}
    
    #rootcontainer {{
      display: flex;
    }}
    
    #site_name {{
      display: block;
      font-size: 2em;
      margin-block-start: 0.67em;
      margin-block-end: 0.67em;
      margin-inline-start: 0;
      margin-inline-end: 0;
      font-weight: 700;
    }}
    
    #site_name,
    .app-header h1,
    .app-header h2,
    .app-header h3,
    .app-header h4,
    .app-header h5,
    .app-header h6 {{
      color: #fff;
    }}
    
    .app-header p {{
      color: #999;
    }}
    
    a:hover {{
      color: #222;
    }}
    
    code {{
      font-family: monospace, monospace;
      font-size: 1em;
      color: #000;
    }}
    
    pre {{
      overflow: auto;
    }}
    
    pre code {{
      font-size: 0.8em;
    }}
    
    ::selection {{
      background: rgba(175, 186, 196, 0.4);
    }}
    
    ::-moz-selection {{
      background: rgba(175, 186, 196, 0.4);
    }}
    
    .app-header {{
      padding: 2vw;
      background: #242930;
      text-align: center;
    }}
    
    .app-header-social {{
      font-size: 2em;
      color: #fff;
    }}
    
    .app-header-social a {{
      margin: 0 0.1em;
      color: #666;
    }}
    
    .posts {{
      margin: 0 0 4vw 5vw;
    }}
    
    .posts a {{
      color: #f04859;
      transition: color 0.35s;
      text-decoration: none;
    }}
    
    .posts h1 {{
      margin-left: 0;
    }}
    
    .post-title {{
      color: #222;
    }}
    
    .post-content pre {{
      border-left: 0.4em solid rgba(87, 204, 138, 0.8);
      padding-left: 1em;
    }}
    
    .post-content img {{
      max-width: 100%;
    }}
    
    @media screen and (max-width: 450px) {{
      .info {{
        display: block;
        text-align: center;
      }}
    
      .info h1 {{
        margin: 0;
      }}
    }}
    
    @media (min-width: 940px) {{
      .app-header {{
        position: fixed;
        top: 0;
        left: 0;
        width: 20vw;
        height: 100%;
      }}
    
      .app-container {{
        margin-left: 20vw;
        margin-right: 2vw;
        width: 70vw;
        padding-right: 3vw;
      }}
    }}
    
    @media (max-width: 940px) {{
      .app-header {{
        padding: 5vw 4vw 3vw 4vw;
        background: #242930;
        text-align: center;
      }}
    
      .app-container {{
        width: 92vw;
      }}
    }}
    
    
    /*--blog----*/
    
    .blog-grid {{
      margin: 0 0 2em 2em;
    }}
    
    .blog-list-grid {{
      column-count: 3;
      column-gap: 30px;
    }}
    
    .blog-list {{
      float: left;
      width: 100%;
      -webkit-column-break-inside: avoid;
      page-break-inside: avoid;
      break-inside: avoid;
      page-break-inside: avoid;
    
      margin: 0 0 30px 0;
      background-color: #FFFFFF;
      -moz-box-shadow: 0 0 15px 2px rgba(0, 0, 0, 0.05);
      -o-box-shadow: 0 0 15px 2px rgba(0, 0, 0, 0.05);
      -webkit-box-shadow: 0 0 15px 2px rgba(0, 0, 0, 0.05);
      box-shadow: 0 0 15px 2px rgba(0, 0, 0, 0.05);
    }}
    
    .blog-list-description {{
      padding: 0 25px;
    }}
    
    .blog-list-description h4 {{
      color: #424C4C;
      font-size: 20px;
      line-height: 1.2;
      margin-bottom: 20px;
      margin-top:0;
    }}
    
    .blog-list-date {{
      color:#666;
      font-size:14px;
    }}
    
    .blog-list-description h4 a {{
      color: #f04859;
    }}
    
    .blog-list-description p {{
      font-size: 16px;
      line-height: 1.5;
    }}
    
    @media only screen and (max-width: 921px) {{
      .blog-list-grid {{
        column-count: 2;
      }}
    
    }}
    
    @media only screen and (max-width: 767px) {{
      .blog-list-grid {{
        column-count: 1;
      }}
    
    }}
    
    img {{
      max-width: 100%;
      height: auto;
    }}
    </style>
</head>
<!-- Google tag (gtag.js) -->
<script async src="https://www.googletagmanager.com/gtag/js?id=G-7T5E2GTJF4"></script>
<script>
  window.dataLayer = window.dataLayer || [];
  function gtag(){{dataLayer.push(arguments);}}
  gtag('js', new Date());

  gtag('config', 'G-7T5E2GTJF4');
</script>
<body>
<div id="root">
    <div id="rootcontainer">
        <div>
            <div>
                <header class="app-header">
                    <a href="/">
                        <div class="app-header-avatar">
                            <img src="/codebeats_logo.svg" alt="React Logo" />
                        </div>
                    </a>
                    <a href="/"><span id="site_name">{BLOG_TITLE}</span></a>
                    <p>{BLOG_INTRO}</p>
                    <div class="app-header-social">
                        <a target="_blank" href="https://github.com/{GITHUB_HANDLE}" rel="noreferrer noopener">
                            <svg xmlns="http://www.w3.org/2000/svg" width="35" height="35" viewBox="0 0 24 24" fill="none" stroke="currentColor" strokeWidth="2" strokeLinecap="round" strokeLinejoin="round" class="icon icon-github">
                            <title>github</title>
                            <path d="M9 19c-5 1.5-5-2.5-7-3m14 6v-3.87a3.37 3.37 0 0 0-.94-2.61c3.14-.35 6.44-1.54 6.44-7A5.44 5.44 0 0 0 20 4.77 5.07 5.07 0 0 0 19.91 1S18.73.65 16 2.48a13.38 13.38 0 0 0-7 0C6.27.65 5.09 1 5.09 1A5.07 5.07 0 0 0 5 4.77a5.44 5.44 0 0 0-1.5 3.78c0 5.42 3.3 6.61 6.44 7A3.37 3.37 0 0 0 9 18.13V22"></path>
                            </svg>
                        </a>
                        <a target="_blank" href="https://twitter.com/{TWITTER_HANDLE}" rel="noreferrer noopener">
                            <svg xmlns="http://www.w3.org/2000/svg" width="35" height="35" viewBox="0 0 24 24" fill="none" stroke="currentColor" strokeWidth="2" strokeLinecap="round" strokeLinejoin="round" class="icon icon-twitter">
                            <title>twitter</title>
                            <path d="M23 3a10.9 10.9 0 0 1-3.14 1.53 4.48 4.48 0 0 0-7.86 3v1A10.66 10.66 0 0 1 3 4s-4 9 5 13a11.64 11.64 0 0 1-7 2c9 5 20 0 20-11.5a4.5 4.5 0 0 0-.08-.83A7.72 7.72 0 0 0 23 3z"></path>
                            </svg>
                        </a>
                    </div>
                </header>
            </div>
            <main class="app-container">
                <article class="posts">
                    <header class="post-header">
                        <h1 class="post-title">{blog_post_title}</h1>
                        <div class="post-meta">
                            <div>
                                📅 <span>{date_to_nice_string(blog_post_date)}</span>
                            </div>
                            <div>
                                🔖 <span>{blog_post_tags}</span>		
                            </div>
                        </div>
                    </header>
                    <div class="post-content">{blog_post_html}</div>
                    <a href="/">↩ Go back</a>
                </article>
            </main>
        </div>
    </div>
</div>
</body>
</html>
"""

# %%
s3_client = boto3.client('s3', aws_access_key_id=AWS_ACCESS_KEY, aws_secret_access_key=AWS_SECRET_KEY, region_name=AWS_REGION)

def upload_to_s3(file_path, s3_key, acl='public-read'):
    s3_client.upload_file(file_path, BUCKET_NAME, s3_key, ExtraArgs = {'ContentType': 'text/html; charset=utf-8'})

def save_and_upload_html(html_content, local_path, s3_key):
    # Save the HTML content to a file
    with open(local_path, "w", encoding="utf-8") as file:
        file.write(html_content)

    # Upload the file to S3
    upload_to_s3(local_path, s3_key)

# %%
from datetime import datetime
from io import BytesIO
def create_sitemap():
    event = datetime.utcnow()
    dynamodb = boto3.client('dynamodb', region_name=AWS_REGION, aws_access_key_id=AWS_ACCESS_KEY, aws_secret_access_key=AWS_SECRET_KEY)
    
    # Assuming AWS_DYNAMO_TABLE, SITE_CANONICAL_URL, BLOG_SEO_SUBFOLDER, AWS_S3_BUCKET are defined elsewhere
    params = {
        "TableName": AWS_DYNAMO_TABLE,
        "ProjectionExpression": "title, post_folder, post_body, date_modified",
    }

    # Scan all blog posts data
    response = dynamodb.scan(**params)
    lastmod_value = event.strftime('%Y-%m-%dT%H:%M:%S.%f')[:-3] + 'Z'
    posts = f'''<?xml version="1.0" encoding="UTF-8"?>
                <urlset xmlns="http://www.sitemaps.org/schemas/sitemap/0.9">
                    <url>
                        <loc>{SITE_CANONICAL_URL}</loc>
                        <lastmod>{lastmod_value}</lastmod>
                        <changefreq>monthly</changefreq>
                        <priority>0.8</priority>
                    </url>
                '''

    for blogpost in response.get("Items", []):
        posts += f'''<url>
                        <loc>{SITE_CANONICAL_URL}{BLOG_SEO_SUBFOLDER}/{blogpost["post_folder"]["S"]}/index.html</loc>
                        <lastmod>{blogpost["date_modified"]["S"]}</lastmod>
                        <changefreq>monthly</changefreq>
                    </url>'''

    posts += "</urlset>"

    s3_client = boto3.client("s3")

    # Upload the sitemap to S3
    s3_client.upload_fileobj(
        Fileobj=BytesIO(posts.encode('utf-8')),
        Bucket=BUCKET_NAME,
        Key="sitemap.xml",
        ExtraArgs={"ContentType": "application/xml; charset=utf-8"},
    )

    print("Successfully uploaded your sitemap.")

# %%
def generate(whole_site,postid=''):
    dynamodb = boto3.resource('dynamodb', region_name=AWS_REGION, aws_access_key_id=AWS_ACCESS_KEY, aws_secret_access_key=AWS_SECRET_KEY)
    table = dynamodb.Table(AWS_DYNAMO_TABLE)
    
    response = table.scan(
        ProjectionExpression="title, post_folder, post_body, post_date, image, summary, post_tags, #pb",
        FilterExpression="#pb = :published",
        ExpressionAttributeNames={"#pb": "published"},
        ExpressionAttributeValues={":published": True}
    )
    
    blogposts = response.get("Items", [])
    
    blogposts_ordered = sorted(blogposts, key=lambda x: date_to_unix(x["post_date"]), reverse=True)
    
    html_output = ""
    for blogpost in blogposts_ordered:
        html_output += f"""
            <div class="card-grid-space" key={blogpost['post_folder']}>
                <div class="blog-list">
                    <div class="blog-list-img">
                        <img src={SITE_CANONICAL_URL + blogpost['image']} />
                    </div>
                    <div class="blog-list-description">
                        <span class="blog-list-date">{date_to_nice_string(blogpost['post_date'])}</span>
                        <h4>
                            <a class="card" href="/{BLOG_SEO_SUBFOLDER}/{blogpost['post_folder']}/index.html">
                                {blogpost['title']}
                            </a>
                        </h4>
                        <p>
                            {blogpost['summary']}
                        </p>
                    </div>
                </div>
            </div>
        """
    
    html_output = HTMLBODY + html_output + FOOTER
    
    # Save and upload the main HTML file
    save_and_upload_html(html_output, "codebeats/index.html", 'index.html')
    
    if whole_site == True:
        for blogpost in blogposts_ordered:
            blogpost_id = blogpost['post_folder']
            blogpost_title = blogpost['title']
            blogpost_url = SITE_CANONICAL_URL + BLOG_SEO_SUBFOLDER + '/' + blogpost_id
            blogpost_date = blogpost['post_date']
            blogpost_html = blogpost['post_body']
            blogpost_tags = blogpost['post_tags']
            blogpost_output = HTML_BLOGPOST_BODY(blogpost_title,blogpost_url,blogpost_date,blogpost_html,blogpost_tags)
            
            # Define the directory path
            directory_path = "codebeats/blogpost/" + blogpost_id
            
            # Create the directory if it doesn't exist
            os.makedirs(directory_path, exist_ok=True)
            
            # Save and upload the blogpost HTML file
            save_and_upload_html(blogpost_output, os.path.join(directory_path, "index.html"), f'blogpost/{blogpost_id}/index.html')
            create_sitemap()
    else:
            blogpost_id = postid
            blogpost = get_blogpost_content(blogpost_id)
            blogpost_title = blogpost['title']['S']
            blogpost_url = SITE_CANONICAL_URL + BLOG_SEO_SUBFOLDER + '/' + blogpost_id
            blogpost_date = blogpost['post_date']['S']
            blogpost_html = blogpost['post_body']['S']
            blogpost_tags = blogpost['post_tags']['S']
            blogpost_output = HTML_BLOGPOST_BODY(blogpost_title,blogpost_url,blogpost_date,blogpost_html,blogpost_tags)
            
            # Define the directory path
            directory_path = "codebeats/blogpost/" + blogpost_id
            
            # Create the directory if it doesn't exist
            os.makedirs(directory_path, exist_ok=True)
            
            # Save and upload the single blogpost HTML file
            save_and_upload_html(blogpost_output, os.path.join(directory_path, "index.html"), f'blogpost/{blogpost_id}/index.html')
            create_sitemap()

# %%
# RE-GENERATE AND PUBLISH FULL STIE
generate(True)

# %%
# PUBLISH A SINGLE ARTICLE
generate(False,'the-rise-of-brave-and-fall-of-google-chrome')
# Out:
# Successfully uploaded your sitemap.

# %%
# REPUBLISH SITEMAP
create_sitemap()
# Out:
# Successfully uploaded your sitemap.
